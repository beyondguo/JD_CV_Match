# %%
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
import beyondnlp
from beyondnlp import *
import time
# Out:
# E:\learningsoft\anadonda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# You have imported 'beyondnlp' !

# %%
wv_all = KeyedVectors.load_word2vec_format(datapath('F:/MyDownloads/merge_sgns_bigram_char300.txt/merge_sgns_bigram_char300.txt'), binary=False)

# %%
vocab = wv_all.vocab # a vocabulary dict
wv_all.most_similar('英语')

# %%
from sklearn.feature_extraction.text import  TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import time
################句子转化成向量##############
def sentence2vec(sentence):
    t1 = time.time()
    words = text2words(sentence)
    t2 = time.time()
    print('.',end='')
    sen_v = np.zeros((300))
    n = 0
    t3 = time.time()
    for word in words:
        if word in vocab.keys() and word!='':
            n += 1
            word_v = wv_all[word]
            sen_v = sen_v+word_v
    if n>0:
        sen_v = sen_v/n
    t4 = time.time()
    return sen_v

####### 端到端：从文件输出可以直接聚类的向量列表：##############
def from_file_to_vector_list(filepath):
#     text = open(filepath,'r',encoding='utf-8')
#     sentences = text2sentences(text)
    sentences = file2sentences(filepath=filepath)
    print("Length of sentences:",len(sentences))
    sentences_v = []
    for sentence in sentences:
        v = sentence2vec(sentence)
        sentences_v.append(np.array(v))
    print("Length of vectors:",len(sentences_v))
    return [sentences,sentences_v]

# %%
# duty_filepath = 'IT_duty.txt'
# job_filepath = 'IT_job.txt'
# duty_sentences,duty_vectors = from_file_to_vector_list(duty_filepath)
# job_sentences,job_vectors = from_file_to_vector_list(job_filepath)
op_filepath = 'C:/Users/x1c/Documents/WeChat Files/LIghTGBY/Files/sf_cvs\sf_cvs'
op_sentences,op_vectors = from_file_to_vector_list(op_filepath)
# sentences = ['猎上顺丰简历项目','猎上顺丰简历项目','猎上顺丰简历项目']
# for s in sentences:
#     t1 = time.time()
#     words = text2words(s)
#     t2 = time.time()
#     print("beyond:",t2-t1,'s')
# Out:
# Length of sentences: 807
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Length of vectors: 807

# %%
from pandas.core.frame import DataFrame
import pandas as pd
pd1 = DataFrame(op_sentences,columns=['sentences'])
pd2 = DataFrame(op_vectors)
pd.concat([pd1,pd2],axis=1)
# Out:
#                                              sentences         0         1  \
# 0    警示：顺丰公司及其下属分公司实施招聘、培训不收取任何费用、押金等，敬请各位求职者知晓并转告，...  0.096754 -0.117912
# 1    4、组织、协调 、沟通能力强，具备较强的经营及综合分析能力，有良好的职业道德操守，强烈的责任...  0.455048  0.050442
# 2                      1、\t年龄25岁-45岁，大专及以上学历，通讯或电子类专业；  0.531034  0.168503
# 3                                3、有良好的职业道德操守，为人诚信、正直；  0.432536  0.224585
# 4                  1、学历要求：本科及以上学历，物流或运输管理类专业，管理专业优先考虑；  0.515522  0.056722
# 5                               3. 具备良好的团队合作精神、高度的责任感。  0.357102  0.024965
# 6    4、 有良好的职业道德操守，工作认真负责，执行力强，能吃苦耐劳，有食品安全意识，具备良好沟通...  0.412193  0.038051
# 7                           3、2年以上物流工作经验，有1年以上管理经验者优先；  0.619090  0.144588
# 8    3、富有责任心、学习力、领悟力、市场洞察力、热点事件敏感度，具备深厚的文案功底和优秀的文字驾...  0.309390 -0.096649
# 788                    3、理解企业管理方法理论，熟悉企划管理工具运用及相关规则制定。  0.380052 -0.100055
# 789                           1、本科及以上学历， 物流或管理类专业优先考虑；  0.509877  0.046989
# 790                                 3、本科以上学历，5年以上工作经验；  0.617579  0.251303
# 791                         4、具备良好的沟通表达理解能力，较强的逻辑思维能力。  0.455223 -0.119745
# 792             2、从事大型连锁或集团企业管理，先后从事市场、营销、人力资源等管理工作者优先  0.450986 -0.143339
# 793    2、3年工作经验，2年以上团队管理+市场销售（或客户服务）经验，有大中型物流公司工作经验优先；  0.384957 -0.001478
# 794                              2.有较全面的管理协调和处理突发事件能力；  0.396640 -0.111887
# 795        计算机及相关办公软件应用熟练1、本科以上学历，运输、物流管理等相关管理类专业优先考虑；  0.465684  0.053679
# 796  警示信息：顺丰速运有限公司及其下属分公司实施招聘、培训不收取任何费用、押金等，敬请各位求职者...  0.118658 -0.118696
# 797                               3、 聪明、独立思维、逻辑性强、有潜质；  0.495875 -0.044630
# 798                    2、5年以上工作经验（其中最少一年以上本公司企划岗工作经历）；  0.283097  0.055528
# 799                              5、能够承受较大的工作压力及弹性工作时间；  0.468634  0.060186
# 800                3、有较强的风险管控能力、沟通协调能力、系统&逻辑思维能力、学习能力。  0.392901 -0.102288
# 801                                         \t擅长利润管理；  0.261155  0.084441
# 802                                4、良好的逻辑思维能力和沟通协调能力。  0.494396 -0.061844
# 803        6、具备较优秀的组织协调沟通能力，服务意识、团队意识较强，能处理一般突发事件任职要求：  0.469093 -0.045897
# 804                                          以上岗位公司提供：  0.401907 -0.081075
# 805  4、综合素质能力的要求：熟练使用办公软件，尤其是PPT/EXCEL/VISIO等工具的运用1...  0.383686  0.015927
# 806                                1、本科及以上学历，市场营销专业优先；  0.431937  0.187568
#
#             2         3         4         5         6         7         8  \
# 0   -0.144978 -0.269364 -0.021389 -0.188047 -0.281703  0.438700  0.111230
# 1    0.060253 -0.102815 -0.185731 -0.240536 -0.049945  0.294404  0.096727
# 2   -0.300045 -0.116976 -0.235031 -0.191508 -0.024423  0.142978  0.173054
# 3    0.146905 -0.184905 -0.100648 -0.150792  0.000037  0.292498  0.094415
# 4   -0.165576 -0.077540 -0.247009 -0.382358 -0.103021  0.248798  0.120004
# 5   -0.046668 -0.003902 -0.186469  0.049052 -0.055777  0.455635  0.002992
# 6    0.028963 -0.087588 -0.217819 -0.095565  0.040825  0.391472 -0.084854
# 7   -0.175008 -0.077515 -0.324859 -0.329386  0.057191  0.226283  0.072518
# 8   -0.000491 -0.070516 -0.161305 -0.100842 -0.145575  0.212044  0.062190
# 9   -0.072064 -0.217346 -0.262989 -0.192643 -0.095644  0.370587  0.151380
# 10   0.214871 -0.049200 -0.178925  0.010045 -0.261103  0.204946 -0.193940
# 11  -0.019052 -0.118581 -0.324969 -0.392866 -0.117428  0.339574  0.167843
# 12  -0.311666 -0.111367 -0.284232 -0.325093 -0.003548  0.287946  0.095403
# 13  -0.284422 -0.241231 -0.390022 -0.406661 -0.190229  0.481463 -0.093140
# 14  -0.024287  0.055627 -0.154249 -0.208478  0.014201  0.222016  0.174947
# 9    0.124890 -0.123850  0.112044 -0.487424
# 10   0.118266  0.209183  0.035660 -0.486199
# 11  -0.053218 -0.011099 -0.019499 -0.543221
# 12   0.118015 -0.098905  0.073945 -0.352184
# 13   0.239900 -0.047148  0.188090 -0.434179
# 14   0.190860  0.171236  0.126527 -0.428962
# 15  -0.014750 -0.103894  0.152954 -0.438655
# 16   0.155492 -0.000978  0.570182 -0.473439
# 17   0.055957  0.035535  0.004704 -0.327133
# 18  -0.011568 -0.145077  0.111966 -0.474237
# 19   0.125813 -0.028718  0.091571 -0.516609
# 20   0.038056  0.128850  0.171352 -0.489834
# 21   0.385916  0.064982  0.179051 -0.196878
# 22   0.045899  0.118506 -0.014001 -0.460339
# 23   0.208623  0.002924  0.089982 -0.294334
# 24   0.125049  0.087488  0.211829 -0.300149
# 25  -0.032220  0.174587  0.083188 -0.277014
# 26  -0.047271  0.020918  0.321373 -0.117036
# 27   0.163950 -0.023915 -0.031181 -0.469500
# 28   0.066676  0.011663  0.044498 -0.383690
# 29   0.065316  0.182501  0.153512 -0.423893
# ..        ...       ...       ...       ...
# 777  0.179460  0.014499 -0.036424 -0.425300
# 778  0.102499  0.062361  0.058875 -0.477056
# 779  0.035273 -0.164277  0.137969 -0.415939
# 780  0.148345  0.059297  0.174261 -0.406798
# 781  0.008332 -0.062175  0.095245 -0.391531
# 782  0.085867  0.002707 -0.043857 -0.585883
# 783  0.426459  0.235481  0.136313 -0.307272
# 784  0.292299 -0.025783  0.805799 -0.369442
# 785 -0.053188 -0.122331  0.132847 -0.409081
# 786  0.032140  0.052155  0.199425 -0.363016
# 787  0.105285 -0.016972  0.038705 -0.426203
# 788  0.094981 -0.063137  0.087579 -0.364481
# 789 -0.001008  0.000738  0.414822 -0.420746
# 790  0.089564 -0.043066  0.397028 -0.381256
# 791  0.045362  0.146058  0.138131 -0.439557
# 792  0.105471  0.020277  0.014021 -0.391083
# 793  0.060325 -0.114695  0.032325 -0.359219
# 794 -0.087009 -0.027804 -0.121586 -0.412767
# 795  0.052560  0.089839  0.312978 -0.457467
# 796 -0.107065 -0.035352  0.183660 -0.359054
# 797  0.180738  0.101040  0.094420 -0.534818
# 798  0.086943 -0.080986  0.162859 -0.348227
# 799  0.133327  0.052596  0.060528 -0.240432
# 800  0.215533  0.024156  0.063829 -0.492302
# 801 -0.021701  0.267098 -0.238418 -0.481384
# 802  0.235793  0.223675  0.156839 -0.540638
# 803  0.018474  0.153160  0.044070 -0.446808
# 804  0.069503 -0.275992 -0.076915 -0.338482
# 805  0.036065  0.166725  0.182983 -0.492287
# 806  0.120324 -0.049344  0.554837 -0.396960
#
# [807 rows x 301 columns]

# %% [markdown]
# ## K-means 聚类：

# %%
### 进行K-means聚类，并把结果写进csv文件中：

def cluster_vectors(name,sentences,vectors,num_clusters=5):
    num_clusters = num_clusters
    km_cluster = KMeans(n_clusters=num_clusters, max_iter=100, n_init=40, \
                        init='k-means++',n_jobs=-1)
    class_result = km_cluster.fit_predict(vectors)
    print("Predicting result: \n", class_result)
    vectors_pd = DataFrame(vectors)
    sentences_pd = DataFrame(sentences,columns=['sentence'])
    class_pd = DataFrame(class_result,columns=['class'])
    final_result = pd.concat([class_pd,sentences_pd,vectors_pd], axis=1)
    final_result.to_csv("%s_"%name+"cluster.csv", sep=',', header=False)
    print("文件："+"%s_"%name+"cluster.csv","已经写入并保存！")
    v_c_pd = pd.concat([vectors_pd,class_pd],axis=1)
    v_c_pd.to_csv("%s_"%name+"v_c.csv",sep=',', header=False)
    print("文件："+"%s_"%name+"v_c.csv","已经写入并保存！")
    
    ### 将每一类的文本单独写进一个TXT文件：
#     for i in range(num_clusters):
#         s = final_result['sentence'][final_result['class']==i]
#         s = np.array(s)
#         f = open('cluster_results/%s-text%d.txt'%(name,i),'w',encoding='utf-8')
#         for each in s:
#             f.write(each)
#         f.close()
#         print("聚类文件："+'cluster_results/%s-text%d.txt'%(name,i),"已经写入并保存！")
#     return final_result

# %%
# duty_final_result = cluster_vectors(classname='duty',sentences=duty_sentences,vectors=duty_vectors)
# job_final_result = cluster_vectors(classname='job',sentences=job_sentences,vectors=job_vectors)
num_clusters = 6
op_final_result = cluster_vectors(name='op_req',sentences=op_sentences,vectors=op_vectors,num_clusters=num_clusters)
# Out:
# Predicting result:
#  [0 5 3 5 3 5 5 0 5 0 5 0 0 0 5 0 3 5 0 5 5 0 0 2 2 2 0 0 0 5 5 0 0 2 5 5 5
#  5 0 3 2 5 0 3 5 0 2 0 5 5 0 5 2 5 0 4 0 3 5 3 0 0 3 0 3 0 0 5 2 3 1 0 0 0
#  0 3 5 2 5 0 0 0 5 0 0 3 5 0 2 0 0 3 0 2 3 5 5 5 3 0 0 3 5 0 5 0 0 0 5 5 5
#  5 0 2 0 2 0 5 4 5 0 0 0 0 5 3 0 5 0 5 0 0 5 0 2 0 5 0 0 5 5 5 2 3 0 5 0 2
#  2 5 0 0 2 5 0 5 0 0 5 2 2 5 0 5 0 0 0 5 5 1 5 3 0 3 3 2 0 3 4 4 3 3 4 4 5
#  0 0 0 3 3 0 3 0 3 3 1 2 5 0 0 5 5 0 3 5 0 0 5 2 3 0 0 0 4 5 5 1 5 5 2 0 5
#  3 3 5 4 0 2 3 5 5 5 0 3 2 3 0 5 2 5 3 5 2 3 2 1 0 0 5 4 3 0 3 3 4 0 5 5 0
#  5 0 0 5 5 5 0 3 0 2 3 3 0 0 0 0 0 2 5 3 0 2 2 1 5 3 2 0 0 5 5 5 2 5 3 0 5
#  3 5 5 5 2 5 5 5 5 5 5 0 0 0 5 0 5 5 2 5 0 0 3 5 5 0 5 5 0 3 5 2 5 0 5 0 5
#  0 5 5 0 0 0 0 5 0 3 0 2 5 5 0 5 3 5 3 5 0 3 1 5 5 5 5 1 0 0 0 5 5 0 0 0 3
#  3 5 2 5 0 0 0 5 0 0 5 0 3 3 0 5 2 0 2 5 0 5 3 0 0 3 5 0 2 5 0 3 0 5 2 3 5
#  5 5 5 5 5 5 5 0 2 5 5 0 3 2 0 3 3 0 0 3 3 0 0 3 0 5 5 3 5 5 2 0 2 0 5 0 0
#  0 0 2 5 0 5 5 3 0 5 0 3 0 5 2 3 0 0 3 5 3 5 0 0 0 5 5 5 0 0 3 5 0 5 0 5 0
#  5 5 5 5 0 2 0 0 0 0 3 0 0 5 5 5 5 3 2 3 0 0 0 0 0 3 5 2 2 3 0 0 0 5 5 5 0
#  5 5 0 0 0 0 0 3 3 0 5 2 5 5 2 0 0 0 0 0 3 3 0 0 5 2 0 5 5 3 5 0 5 3 3 2 0
#  0 5 5 0 5 5 0 5 5 5 2 0 5 0 5 0 2 0 5 5 5 0 4 3 0 0 3 3 5 5 5 0 3 0 0 5 5
#  5 5 3 0 0 0 5 0 2 2 0 5 5 5 2 5 5 0 0 3 3 0 4 5 5 3 0 0 2 3 2 3 5 2 2 5 5
#  5 3 0 2 3 5 0 0 3 5 5 0 3 0 2 0 2 5 5 3 0 5 2 0 3 0 0 0 5 3 5 5 5 0 0 5 4
#  5 0 0 5 0 3 0 0 0 5 5 4 0 0 3 5 5 2 5 0 0 3 0 5 0 0 2 5 5 1 4 0 3 0 0 0 4
#  0 5 3 0 2 5 3 0 3 1 5 3 0 3 0 2 5 0 0 5 0 3 0 0 0 3 0 5 0 3 0 5 5 3 0 5 5
#  3 0 5 5 5 0 0 2 0 5 1 0 3 5 5 5 3 3 5 5 3 3 0 0 0 3 0 3 0 5 0 5 0 0 0 0 0
#  5 5 0 2 0 4 0 3 5 0 5 0 3 3 5 0 0 5 3 0 5 0 5 5 0 5 5 0 2 3]
# 文件：op_req_cluster.csv 已经写入并保存！
# 文件：op_req_v_c.csv 已经写入并保存！

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def generate_cloud(classname):
    for i in range(num_clusters):
        f = open('cluster_results/%s-text%d.txt'%(classname,i),'r',encoding='utf-8')
        text = f.read()
        cut_words = jieba.lcut(text)
        new_text = '.'.join(cut_words)
        font = 'C:/Windows/Fonts/simfang.ttf'
        wc = WordCloud(collocations=False, font_path=font, width=500, height=500, margin=2).generate(new_text)
        plt.imshow(wc)
        plt.axis("off")
        plt.title(classname+str(i))
        plt.show()
        wc.to_file('cluster_results/cloud_images/%s-%d.png'%(classname,i))

# %%
# generate_cloud('duty')
# generate_cloud('job') 
generate_cloud('op')

# %% [markdown]
# ## T-SNE降维可视化：

# %%
from sklearn.manifold import TSNE

# %%
duty_embedded = TSNE(n_components=2,early_exaggeration=100).fit_transform(duty_vectors)
job_embedded = TSNE(n_components=2,early_exaggeration=100).fit_transform(job_vectors)
# tsne=pd.DataFrame(tsne.embedding_,index=data_zs.index) #转换数据格式

# d=tsne[r[u'聚类类别']==0]
# plt.plot(d[0],d[1],'r.')
# d=tsne[r[u'聚类类别']==1]
# plt.plot(d[0],d[1],'go')
# d=tsne[r[u'聚类类别']==2]
# plt.plot(d[0],d[1],'b*')
# plt.show()

# %%
len(duty_embedded[:,1])
# Out:
# 1610

# %%
plt.scatter(duty_embedded[:,0],duty_embedded[:,1])
plt.show()

# %%
plt.scatter(job_embedded[:,0],job_embedded[:,1])
plt.show()

# %%
len(text2sentences('到底是怎么,回事到底，是怎么回事,到底是，怎么回事到,底是怎么,回事，到底是怎,么回事到底,是怎么回事到底是怎么回事到底是怎么回事到底是怎么回事儿！！'))
# Out:
# 2
